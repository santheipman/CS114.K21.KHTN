# %%
# -*- coding: utf-8 -*-
from underthesea import word_tokenize
import re
import VietnameseTextNormalizer.ReleasePython3.VietnameseTextNormalizer as nm
import pandas as pd
import numpy as np

# %%
def removeConsecutiveDuplicates(S): 
    S = list(S.rstrip()) 
    
    n = len(S)  
    
    if (n < 2) : 
        return S[0]
           
    j = 0
       
    for i in range(n):  
        if (S[j] != S[i]): 
            j += 1
            S[j] = S[i]  
      
    j += 1
    S = S[:j]
    return "".join(S)

# %%
def preprocessing(s, show_stepbystep=False, remove_stop_words=True):
    if show_stepbystep:
        print("original:")
        print(s)
        print()
    
    # remove 'Xem thêm'
    s = re.sub('Xem thêm', '', s)
    if show_stepbystep:
        print("remove xt:")
        print(s)
        print()

    # convert to lower case
    s = s.lower()
    if show_stepbystep:
        print("lowercase:")
        print(s)
        print()
    
    # normalize Vietnamese
    s = nm.ASRNormalize(s)
    if show_stepbystep:
        print("normalized Vietnamese:")
        print(s)
        print()
        
    # remove urls and hashtags
    s = re.sub(r'http\S+', '', s)
    s = re.sub(r'#\S+', '', s)
    if show_stepbystep:
        print('remove urls and hashtags:')
        print(s)
        print()
    
    # remove email address
    s = re.sub(r'\S*@\S*\s?', '', s)
    if show_stepbystep:
        print('remove email addresses:')
        print(s)
        print()
    
    # split into words
    tokens = word_tokenize(s)
    if show_stepbystep:
        print('tokenize:')
        print(tokens)
        print()
    
    # remove punctuation and number
    words = [word for word in tokens if re.sub(r"\s+", "", word).isalpha()]
    if show_stepbystep:
        print('remove punctuation:')
        print(words)
        print()
    
    # remove stop words
    if remove_stop_words:
        words = [word for word in words if not word in stop_words]
        if show_stepbystep:
            print('remove stop words:')
            print(words)
            print()
    
    # remove consecutive duplicates character
    words = [removeConsecutiveDuplicates(word) for word in words]
    if show_stepbystep:
        print('remove consecutive duplicates character:')
        print(words)
        print()
        
    # remove single character
    words = [word for word in words if len(word)>1]
    if show_stepbystep:
        print('remove single character:')
        print(words)
        print()
    
    return words

# %%
# load stop words list
file = open('vietnamese-stopwords.txt')
stop_words = file.readlines()
file.close()

stop_words = set([word.strip('\n') for word in stop_words])
stop_words
# Out:
# {'sau',
#  'tốt bộ',
#  'khi nào',
#  'lấy số',
#  'như nhau',
#  'cao răng',
#  'hỗ trợ',
#  'gần bên',
#  'nhà việc',
#  'sớm',
#  'biết mình',
#  'nghen',
#  'sở dĩ',
#  'đặt ra',
#  'việc',
#  'tăng thêm',
#  'ngọn nguồn',
#  'thế lại',
#  'trệu trạo',
#  'theo tin',
#  'từ loại',
#  'giữ lấy',
#  'mới hay',
#  'là ít',
#  'đưa về',
#  'có chứ',
#  'ở nhờ',
#  'chung',
#  'chùn chùn',
#  'tôi con',
#  'bấy lâu nay',
#  'hỏi',
#  'ăn làm',
#  'lớn lên',
#  'xăm xắm',
#  'cây nước',
#  'có thế',
#  'hết ý',
#  'tính cách',
#  'qua',
#  'nguồn',
#  'tấn',
#  'chính thị',
#  'dạ',
#  'chưa cần',
#  'tuốt tuột',
#  'còn',
#  'ba bản',
#  'lại ăn',
#  'ấy',
#  'cảm ơn',
#  'nhớ',
#  'nữa là',
#  'lại đây',
#  'ngoài này',
#  'không có gì',
#  'cả ăn',
#  'ăn ngồi',
#  'vở',
#  'quá nhiều',
#  'nghĩ ra',
#  'việc gì',
#  'muốn',
#  'phía trước',
#  'ái dà',
#  'mang nặng',
#  'thường thôi',
#  'cu cậu',
#  'luôn',
#  'lần nào',
#  'phỏng tính',
#  'thà rằng',
#  'đơn vị',
#  'chọn ra',
#  'thật tốt',
#  'vừa qua',
#  'nói tốt',
#  'thường xuất hiện',
#  'đều',
#  'ít khi',
#  'thật lực',
#  'ối giời ơi',
#  'tuy vậy',
#  'bấy nhiêu',
#  'hoàn toàn',
#  'nói ra',
#  'trong số',
#  'nghe rõ',
#  'nhất',
#  'ơ hay',
#  'nhung nhăng',
#  'cũng như',
#  'bấy chừ',
#  'chớ gì',
#  'đầu tiên',
#  'tất thảy',
#  'nhằm khi',
#  'quả thật',
#  'bắt đầu',
#  'thanh điều kiện',
#  'hoặc',
#  'ba họ',
#  'từng thời gian',
#  'xa nhà',
#  'cho tin',
#  'béng',
#  'dẫu mà',
#  'phía bên',
#  'chưa tính',
#  'đáo để',
#  'nhà tôi',
#  'cách đều',
#  'rõ thật',
#  'chưa bao giờ',
#  'thích',
#  'điểm gặp',
#  'bước tới',
#  'cho được',
#  'chuyển',
#  'ào ào',
#  'dùng làm',
#  'chành chạnh',
#  'đúng ra',
#  'phải lại',
#  'chỉn',
#  'chao ôi',
#  'nước quả',
#  'bỏ mình',
#  'tại',
#  'lại người',
#  'nào hay',
#  'tính',
#  'ắt hẳn',
#  'đến gần',
#  'tìm ra',
#  'thanh chuyển',
#  'khiến',
#  'phải tay',
#  'thếch',
#  'trong này',
#  'nghe tin',
#  'khác xa',
#  'veo veo',
#  'đến lúc',
#  'với nhau',
#  'chung quy lại',
#  'đâu có',
#  'dễ thường',
#  'hoặc là',
#  'ý hoặc',
#  'ngày xưa',
#  'chị bộ',
#  'dữ',
#  'từ khi',
#  'về nước',
#  'thậm cấp',
#  'ít nhiều',
#  'bởi vì',
#  'trước',
#  'nói khó',
#  'ạ ơi',
#  'bỏ bà',
#  'thậm chí',
#  'làm lòng',
#  'khó',
#  'phải biết',
#  'về',
#  'nặng mình',
#  'có khi',
#  'được nước',
#  'lần trước',
#  'thật',
#  'ắt thật',
#  'người người',
#  'mợ',
#  'đưa',
#  'có tháng',
#  'cái gì',
#  'lại nói',
#  'ra ý',
#  'ôi chao',
#  'choa',
#  'tính từ',
#  'nước cùng',
#  'cho rằng',
#  'dễ đâu',
#  'là thế nào',
#  'có vẻ',
#  'chúng',
#  'dùng',
#  'ư',
#  'giống người',
#  'ngay lúc',
#  'bản',
#  'tò te',
#  'ít ra',
#  'đến đâu',
#  'bất tử',
#  'chắc người',
#  'á à',
#  'mà lại',
#  'đâu nào',
#  'hay biết',
#  'ơi là',
#  'bộ',
#  'bằng không',
#  'oai oái',
#  'rồi thì',
#  'nhóm',
#  'trệt',
#  'mở mang',
#  'cái họ',
#  'lên ngôi',
#  'đâu đó',
#  'giống nhau',
#  'ngay khi đến',
#  'nghe đâu như',
#  'chung nhau',
#  'chẳng nữa',
#  'thoạt',
#  'một số',
#  'cật lực',
#  'cụ thể',
#  'đã hay',
#  'ăn chung',
#  'đáng kể',
#  'thích cứ',
#  'tìm cách',
#  'đủ điều',
#  'người nhận',
#  'chẳng lẽ',
#  'ông từ',
#  'khác',
#  'à này',
#  'xoẳn',
#  'trả',
#  'cần cấp',
#  'đặt mức',
#  'đại nhân',
#  'ở vào',
#  'thêm giờ',
#  'thanh điểm',
#  'không cần',
#  'tìm',
#  'năm',
#  'cách bức',
#  'cho rồi',
#  'qua đi',
#  'đưa chuyện',
#  'sau đây',
#  'lại',
#  'phải chăng',
#  'nhìn thấy',
#  'tay quay',
#  'hỏi xem',
#  'nhất loạt',
#  'từ ấy',
#  'bán',
#  'cao lâu',
#  'đầy',
#  'vùng',
#  'thà là',
#  'không để',
#  'nhau',
#  'buổi làm',
#  'phỏng như',
#  'nghĩ',
#  'tôi',
#  'chung ái',
#  'chính điểm',
#  'như trên',
#  'nói là',
#  'thời gian sử dụng',
#  'bèn',
#  'chia sẻ',
#  'đành đạch',
#  'vài điều',
#  'nghe hiểu',
#  'à',
#  'nói ý',
#  'số thiếu',
#  'làm lại',
#  'nói đến',
#  'đúng với',
#  'khá tốt',
#  'nếu thế',
#  'đến cùng',
#  'nhất sinh',
#  'phải rồi',
#  'phần',
#  'chính',
#  'chú mày',
#  'quả vậy',
#  'trỏng',
#  'cuốn',
#  'ra lại',
#  'trong ấy',
#  'để cho',
#  'về tay',
#  'sất',
#  'cơ chừng',
#  'nên tránh',
#  'phần việc',
#  'nơi',
#  'lên',
#  'sang',
#  'đại loại',
#  'phía dưới',
#  'cụ thể là',
#  'thốc',
#  'xuống',
#  'quận',
#  'dở chừng',
#  'cô ấy',
#  'bao nả',
#  'chọn bên',
#  'tối ư',
#  'thình lình',
#  'ngôi thứ',
#  'nên người',
#  'ví dù',
#  'cả ngày',
#  'nói chung',
#  'ren rén',
#  'giữa lúc',
#  'xin',
#  'nói trước',
#  'thốt nhiên',
#  'sau sau',
#  'rồi ra',
#  'lúc trước',
#  'làm tại',
#  'ngay khi',
#  'những lúc',
#  'âu là',
#  'nước lên',
#  'không bao lâu',
#  'thật chắc',
#  'hay tin',
#  'mức',
#  'là nhiều',
#  'căn tính',
#  'sau chót',
#  'trong lúc',
#  'giờ lâu',
#  'sáng thế',
#  'ở năm',
#  'cóc khô',
#  'đã đủ',
#  'phải người',
#  'về sau',
#  'tất tần tật',
#  'khỏi',
#  'cách không',
#  'xảy ra',
#  'chết tiệt',
#  'cơn',
#  'ngày nào',
#  'a ha',
#  'nói phải',
#  'nếu cần',
#  'quá thì',
#  'vào đến',
#  'có dễ',
#  'từng',
#  'nhằm để',
#  'khó mở',
#  'mỗi lần',
#  'tháng tháng',
#  'cùng với',
#  'chết nỗi',
#  'dù cho',
#  'ai ai',
#  'ngoải',
#  'ắt',
#  'xem lại',
#  'đánh đùng',
#  'tới thì',
#  'lại giống',
#  'trên',
#  'bằng người',
#  'nấy',
#  'khó thấy',
#  'thiếu',
#  'cao thế',
#  'chưa kể',
#  'phần lớn',
#  'bỗng dưng',
#  'nhờ chuyển',
#  'làm riêng',
#  'cho đến khi',
#  'tuy thế',
#  'ăn chịu',
#  'ô hô',
#  'cứ',
#  'xử lý',
#  'nào là',
#  'những khi',
#  'chợt nghe',
#  'tự tạo',
#  'đáng',
#  'đều đều',
#  'bằng cứ',
#  'về không',
#  'chắc lòng',
#  'vung thiên địa',
#  'con dạ',
#  'chắc hẳn',
#  'chính là',
#  'á',
#  'cho chắc',
#  'theo',
#  'không hay',
#  'đưa vào',
#  'phóc',
#  'tên',
#  'làm vì',
#  'cho biết',
#  'hiểu',
#  'tránh xa',
#  'tới nơi',
#  'cả thể',
#  'có đáng',
#  'quá bán',
#  'không có',
#  'tăm tắp',
#  'nọ',
#  'nhất nhất',
#  'làm sao',
#  'tránh',
#  'đang tay',
#  'qua khỏi',
#  'gần đến',
#  'trở thành',
#  'có số',
#  'lại quả',
#  'sự việc',
#  'thật là',
#  'anh ấy',
#  'dù sao',
#  'sì sì',
#  'cùng ăn',
#  'bài bỏ',
#  'không khỏi',
#  'đặt trước',
#  'tuy là',
#  'tắp tắp',
#  'ví phỏng',
#  'ý da',
#  'mở ra',
#  'cái',
#  'chuyển tự',
#  'gây giống',
#  'đang thì',
#  'dần dà',
#  'tanh',
#  'tốt ngày',
#  'bạn',
#  'bỏ ra',
#  'nhận',
#  'tạo',
#  'dạ bán',
#  'có ngày',
#  'đưa xuống',
#  'sẽ biết',
#  'đã',
#  'tăng',
#  'riu ríu',
#  'phía',
#  'căn cái',
#  'ra vào',
#  'họ xa',
#  'vì chưng',
#  'nếu mà',
#  'nhanh',
#  'cả',
#  'chú mình',
#  'một cách',
#  'ô hay',
#  'phốc',
#  'phót',
#  'bằng',
#  'giờ này',
#  'bỗng không',
#  'đến điều',
#  'dễ ngươi',
#  'bởi tại',
#  'ra',
#  'bài cái',
#  'rốt cuộc',
#  'dài',
#  'xoành xoạch',
#  'dẫu rằng',
#  'khó nói',
#  'vốn dĩ',
#  'do đó',
#  'vùng lên',
#  'tuy nhiên',
#  'đã vậy',
#  'cao thấp',
#  'rằng là',
#  'kể cả',
#  'sang tay',
#  'thuộc bài',
#  'chứ như',
#  'về phần',
#  'thật vậy',
#  'thấp cơ',
#  'không tính',
#  'chứ lị',
#  'dễ gì',
#  'của tin',
#  'giữ ý',
#  'cực lực',
#  'nhân tiện',
#  'bất giác',
#  'nặng căn',
#  'thì phải',
#  'gồm',
#  'nhớ ra',
#  'có phải',
#  'chỉ chính',
#  'đạt',
#  'có thể',
#  'xềnh xệch',
#  'con con',
#  'thoắt',
#  'ứ hự',
#  'lên nước',
#  'lớn nhỏ',
#  'chắc vào',
#  'duy có',
#  'đến cùng cực',
#  'nói rõ',
#  'vâng',
#  'sao bản',
#  'tốt bạn',
#  'so với',
#  'vụt',
#  'tại nơi',
#  'nhìn theo',
#  'bỏ xa',
#  'chết thật',
#  'giữa',
#  'khác khác',
#  'nhất thiết',
#  'nghe thấy',
#  'bất đồ',
#  'lấy được',
#  'ngày tháng',
#  'xin gặp',
#  'vừa',
#  'giống',
#  'thì giờ',
#  'mọi',
#  'chiếc',
#  'vấn đề quan trọng',
#  'vẫn',
#  'thật ra',
#  'biết thế',
#  'lấy',
#  'hay',
#  'nghe được',
#  'thím',
#  'lấy thêm',
#  'ngày đến',
#  'ráo',
#  'phè phè',
#  'điểm chính',
#  'người khác',
#  'đâu như',
#  'khác gì',
#  'văng tê',
#  'bằng ấy',
#  'nhớ bập bõm',
#  'cứ như',
#  'để',
#  'ừ nhé',
#  'này',
#  'cuối',
#  'răng',
#  'thẩy',
#  'bất luận',
#  'đưa tin',
#  'số',
#  'ơi',
#  'ngày qua',
#  'ăn quá',
#  'để lại',
#  'nghiễm nhiên',
#  'khác nào',
#  'thường khi',
#  'làm gì',
#  'không ngoài',
#  'vậy là',
#  'bên bị',
#  'thảo hèn',
#  'vâng dạ',
#  'hay là',
#  'thiếu điểm',
#  'trả trước',
#  'dạ dạ',
#  'ừ thì',
#  'ồ',
#  'chị',
#  'vô hình trung',
#  'cuộc',
#  'lấy làm',
#  'tới',
#  'thuộc từ',
#  'phải khi',
#  'vừa khi',
#  'đúng tuổi',
#  'từ tính',
#  'nhất luật',
#  'pho',
#  'cấp trực tiếp',
#  'ngôi',
#  'cuối điểm',
#  'nói bông',
#  'đến giờ',
#  'phải cách',
#  'từng giờ',
#  'sử dụng',
#  'nào cũng',
#  'thì ra',
#  'thế thì',
#  'giảm thấp',
#  'ở trên',
#  'ủa',
#  'bộ thuộc',
#  'nhưng mà',
#  'tránh khỏi',
#  'từ căn',
#  'tìm việc',
#  'vì sao',
#  'dài ra',
#  'từ điều',
#  'duy chỉ',
#  'tuy đã',
#  'chỉ',
#  'rồi sao',
#  'cha chả',
#  'thốt nói',
#  'nói thêm',
#  'hơn',
#  'tại đây',
#  'nếu có',
#  'không biết',
#  'mang mang',
#  'thường tính',
#  'thường tại',
#  'lúc',
#  'mọi việc',
#  'chăng',
#  'nghe',
#  'thực tế',
#  'thực vậy',
#  'chị ấy',
#  'nước đến',
#  'nhà làm',
#  'từ đó',
#  'mở nước',
#  'nhiều ít',
#  'để giống',
#  'nhất tề',
#  'hay hay',
#  'khi khác',
#  'phía bạn',
#  'vùng nước',
#  'do vì',
#  'làm tôi',
#  'thành ra',
#  'quá trình',
#  'đến cả',
#  'gặp phải',
#  'những muốn',
#  'không nhận',
#  'biết được',
#  'rích',
#  'thộc',
#  'tên chính',
#  'ít có',
#  'điểm',
#  'tất cả',
#  'tự vì',
#  'vừa vừa',
#  'tất cả bao nhiêu',
#  'một cơn',
#  'với lại',
#  'bỏ lại',
#  'mọi nơi',
#  'quá giờ',
#  'rồi sau',
#  'lấy để',
#  'bông',
#  'nhớ lại',
#  'là phải',
#  'vả lại',
#  'riêng',
#  'sang sáng',
#  'vèo vèo',
#  'gần đây',
#  'đó đây',
#  'sau hết',
#  'lời chú',
#  'qua ngày',
#  'không chỉ',
#  'đến ngày',
#  'lâu nay',
#  'tắp lự',
#  'chú khách',
#  'bỏ không',
#  'khi trước',
#  'thực hiện đúng',
#  'luôn tay',
#  'ít lâu',
#  'khó nghĩ',
#  'giảm thế',
#  'bớ',
#  'tốt mối',
#  'ào vào',
#  'ngọt',
#  'nền',
#  'ngõ hầu',
#  'ít biết',
#  'thiếu gì',
#  'loại',
#  'tự',
#  'qua thì',
#  'thốt',
#  'tức tốc',
#  'hiện nay',
#  'ít',
#  'chứ lại',
#  'không những',
#  'con nhà',
#  'ráo cả',
#  'khác thường',
#  'mỗi',
#  'bỗng',
#  'chớ như',
#  'khi nên',
#  'như thế',
#  'coi mòi',
#  'thời gian tính',
#  'thật thà',
#  'cụ thể như',
#  'bởi sao',
#  'tuy rằng',
#  'bị vì',
#  'đến thế',
#  'chưa có',
#  'chắc ăn',
#  'nào',
#  'thôi việc',
#  'có chăng là',
#  'lấy giống',
#  'không còn',
#  'vâng ý',
#  'như ý',
#  'chu cha',
#  'úi chà',
#  'gần xa',
#  'tính căn',
#  'tạo ý',
#  'tức thì',
#  'đến tuổi',
#  'thanh thanh',
#  'ít thôi',
#  'veo',
#  'ráo nước',
#  'thấp thỏm',
#  'lòng không',
#  'ra gì',
#  'người nghe',
#  'có',
#  'bà',
#  'nói lại',
#  'tên cái',
#  'không phải không',
#  'nên',
#  'thanh không',
#  'thấy tháng',
#  'chưa dùng',
#  'tốt',
#  'lấy xuống',
#  'chậc',
#  'trực tiếp làm',
#  'bỏ riêng',
#  'qua chuyện',
#  'tăng cấp',
#  'lượng từ',
#  'chợt nhìn',
#  'mang',
#  'tháng ngày',
#  'thứ bản',
#  'đã lâu',
#  'ba ba',
#  'quả',
#  'khẳng định',
#  'mang lại',
#  'chung cục',
#  'bởi chưng',
#  'sao',
#  'nghe đâu',
#  'cho nhau',
#  'cả nhà',
#  'em',
#  'sốt sột',
#  'vừa lúc',
#  'sự thế',
#  'ào',
#  'cho',
#  'con',
#  'sau nữa',
#  'hãy',
#  'ngày càng',
#  'chầm chập',
#  'gì đó',
#  'đến nỗi',
#  'giống như',
#  'sắp',
#  'phỉ phui',
#  'biết chừng nào',
#  'vào gặp',
#  'bất chợt',
#  'bển',
#  'tập trung',
#  'ăn riêng',
#  'từ tại',
#  'số là',
#  'bằng nhau',
#  'nó',
#  'giờ đi',
#  'kể',
#  'dù dì',
#  'tính phỏng',
#  'ra sao',
#  'ái chà',
#  'thay đổi',
#  'vừa mới',
#  'đã là',
#  'nghe như',
#  'nhờ nhờ',
#  'cái đã',
#  'hay sao',
#  'phụt',
#  'những là',
#  'tiếp đó',
#  'nghĩ xa',
#  'xem',
#  'xon xón',
#  'vị trí',
#  'ông nhỏ',
#  'hết rồi',
#  'từ giờ',
#  'để phần',
#  'cho đang',
#  'xệp',
#  'đảm bảo',
#  'ngồi không',
#  'cả nghĩ',
#  'bỏ mất',
#  'khó chơi',
#  'ối dào',
#  'bộ điều',
#  'những như',
#  'trong khi',
#  'lúc đến',
#  'phè',
#  'làm tăng',
#  'thoạt nhiên',
#  'này nọ',
#  'bao lâu',
#  'thường bị',
#  'chịu chưa',
#  'sự',
#  'từng ấy',
#  'hiện tại',
#  'rút cục',
#  'đây đó',
#  'bản thân',
#  'vậy mà',
#  'mỗi lúc',
#  'có nhà',
#  'đâu đây',
#  'bước đi',
#  'quá mức',
#  'bước',
#  'mở',
#  'úi',
#  'nếu như',
#  'a lô',
#  'ngay cả',
#  'của ngọt',
#  'gặp khó khăn',
#  'giá trị',
#  'phía sau',
#  'vậy',
#  'mỗi ngày',
#  'ngọn',
#  'gặp',
#  'biết đâu chừng',
#  'ai',
#  'trả của',
#  'tốt hơn',
#  'tin',
#  'trước tuổi',
#  'chắc dạ',
#  'cây',
#  'lâu',
#  'người',
#  'thêm vào',
#  'sa sả',
#  'phải không',
#  'làm dần dần',
#  'đã thế',
#  'bởi',
#  'khỏi nói',
#  'bằng như',
#  'chăng chắc',
#  'trển',
#  'lớn',
#  'sao bằng',
#  'ông',
#  'ừ',
#  'để được',
#  'biết',
#  'dễ',
#  'thương ôi',
#  'tanh tanh',
#  'hơn trước',
#  'ắt là',
#  'phần nhiều',
#  'có chuyện',
#  'ít nhất',
#  'lại thôi',
#  'không đầy',
#  'không gì',
#  'chẳng phải',
#  'số người',
#  'làm tắp lự',
#  'vào khoảng',
#  'lúc đó',
#  'thường số',
#  'quan tâm',
#  'buổi ngày',
#  'đưa cho',
#  'ờ ờ',
#  'cho tới',
#  'chịu tốt',
#  'khoảng',
#  'ồ ồ',
#  'lại cái',
#  'tiếp theo',
#  'cấp số',
#  'toà',
#  'chí chết',
#  'bên có',
#  'đưa em',
#  'thế là',
#  'tạo điều kiện',
#  'phăn phắt',
#  'có họ',
#  'điều gì',
#  'lấy thế',
#  'nóc',
#  'nhất định',
#  'giờ đến',
#  'giờ',
#  'sau cùng',
#  'lâu ngày',
#  'cơ',
#  'chứ không phải',
#  'sẽ hay',
#  'nhỉ',
#  'không bao giờ',
#  'bởi đâu',
#  'cha',
#  'hết cả',
#  'chứ',
#  'vậy thì',
#  'có được',
#  'hết nói',
#  'gần',
#  'nhà khó',
#  'chứ còn',
#  'mà vẫn',
#  'từ từ',
#  'nhằm',
#  'có điều',
#  'thấp xuống',
#  'trong ngoài',
#  'đó',
#  'gần hết',
#  'bán thế',
#  'thích ý',
#  'đồng thời',
#  'như là',
#  ...}

# %%
k10 = pd.read_csv("k10/posts_1594272491_8.csv", header=None)
k11 = pd.read_csv("k11/posts_1594251010_7.csv", header=None)
k12 = pd.read_csv("k12/posts_1594208046_4.csv", header=None)
k13 = pd.read_csv("k13/posts_1594221437_4.csv", header=None)
k14 = pd.read_csv("k14/posts_1594216235_5.csv", header=None)

# %%
dataset = pd.concat([k10, k11, k12, k13, k14], ignore_index=True)

# %%
dataset
# Out:
#                                                        0
# 0      [TSSĐH]-THÔNG BÁO TỔ CHỨC LỚP ÔN TẬP CHUẨN BỊ ...
# 1      💗💗 Giao lưu cùng Nhà báo- Nhà thơ Nguyễn P...
# 2      Phòng Công tác Sinh viên thông tin đến sinh vi...
# 3      🔬 Các chuyên ngành đào tạo trường Đại học Kans...
# 4      👉 Bật mí với các bạn một chương trình vô cùng ...
# ...                                                  ...
# 13149  Bạn này vừa đến Trường nộp Giấy kết quả thi TH...
# 13150  Các em nhỏ nhớ đi MHX2020 nha\nChị share để ki...
# 13151  # chào mình đỗ ktpm clc ... bác nào chung khoa...
# 13152  Chào các bạn, phòng Công tác Sinh viên đã đăng...
# 13153                     Những điều Thí sinh cần lưu ý!
#
# [13154 rows x 1 columns]

# %%
dataset[1] = [preprocessing(dataset.iloc[i][0]) for i in range(dataset.shape[0])]

# %%
dataset[2] = [' '.join(dataset.iloc[i][1]) for i in range(dataset.shape[0])]

# %%
dataset
# Out:
#                                                        0  \
# 0      [TSSĐH]-THÔNG BÁO TỔ CHỨC LỚP ÔN TẬP CHUẨN BỊ ...
# 1      💗💗 Giao lưu cùng Nhà báo- Nhà thơ Nguyễn P...
# 2      Phòng Công tác Sinh viên thông tin đến sinh vi...
# 3      🔬 Các chuyên ngành đào tạo trường Đại học Kans...
# 4      👉 Bật mí với các bạn một chương trình vô cùng ...
# ...                                                  ...
# 13149  Bạn này vừa đến Trường nộp Giấy kết quả thi TH...
# 13150  Các em nhỏ nhớ đi MHX2020 nha\nChị share để ki...
# 13151  # chào mình đỗ ktpm clc ... bác nào chung khoa...
# 13152  Chào các bạn, phòng Công tác Sinh viên đã đăng...
# 13153                     Những điều Thí sinh cần lưu ý!
#
#                                                        1  \
# 0      [tsđh, thông báo, tổ chức, lớp, ôn tập, tuyển ...
# 1      [giao lưu, nhà báo, nhà thơ, nguyễn phong việt...
# 2      [phòng, công tác, sinh viên, thông tin, sinh v...
# 3      [chuyên ngành, đào tạo, trường, đại học, kansa...
# 4      [bật mí, chương trình, vô cùng, hấp dẫn, diễn,...
# ...                                                  ...
# 13149  [trường, nộp, giấy, kết quả, thi, thpt, quốc g...
# 13150  [đi, nha, share, kiểu, khai trương, group, sha...
# 13151  [chào, đỗ, ktpm, clc, khoa, làm quen, mail, ed...
# 13152  [chào, phòng, công tác, sinh viên, đăng tải, h...
# 13153                                  [thí sinh, lưu ý]
#
#                                                        2
# 0      tsđh thông báo tổ chức lớp ôn tập tuyển sinh c...
# 1      giao lưu nhà báo nhà thơ nguyễn phong việt phò...
# 2      phòng công tác sinh viên thông tin sinh viên l...
# 3      chuyên ngành đào tạo trường đại học kansai osa...
# 4      bật mí chương trình vô cùng hấp dẫn diễn nhà v...
# ...                                                  ...
# 13149  trường nộp giấy kết quả thi thpt quốc gia xác ...
# 13150  đi nha share kiểu khai trương group share mấy ...
# 13151  chào đỗ ktpm clc khoa làm quen mail edu trường...
# 13152  chào phòng công tác sinh viên đăng tải hướng d...
# 13153                                     thí sinh lưu ý
#
# [13154 rows x 3 columns]

# %%
dataset = dataset.drop_duplicates(ignore_index=True, subset=2)
dataset.shape
# Out:
# (9141, 3)

# %%
np.where(dataset.applymap(lambda x: x == ''))
# Out:
# (array([61]), array([2]))

# %%
dataset.iloc[61]
# Out:
# 0    https://forms.gle/PgdEEVyyeeSjczSy7
# 1                                     []
# 2
# Name: 61, dtype: object

# %%
dataset = dataset.drop([61])
dataset.shape
# Out:
# (9140, 3)

# %%
np.where(dataset.applymap(lambda x: x == ''))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
dataset.isna().sum()
# Out:
# 0    0
# 1    0
# 2    0
# dtype: int64

# %%
dataset.reset_index(drop=True, inplace=True)

# %%
dataset
# Out:
#                                                       0  \
# 0     [TSSĐH]-THÔNG BÁO TỔ CHỨC LỚP ÔN TẬP CHUẨN BỊ ...
# 1     💗💗 Giao lưu cùng Nhà báo- Nhà thơ Nguyễn P...
# 2     Phòng Công tác Sinh viên thông tin đến sinh vi...
# 3     🔬 Các chuyên ngành đào tạo trường Đại học Kans...
# 4     👉 Bật mí với các bạn một chương trình vô cùng ...
# ...                                                 ...
# 9135  Bạn này vừa đến Trường nộp Giấy kết quả thi TH...
# 9136  Các em nhỏ nhớ đi MHX2020 nha\nChị share để ki...
# 9137  # chào mình đỗ ktpm clc ... bác nào chung khoa...
# 9138  Chào các bạn, phòng Công tác Sinh viên đã đăng...
# 9139                     Những điều Thí sinh cần lưu ý!
#
#                                                       1  \
# 0     [tsđh, thông báo, tổ chức, lớp, ôn tập, tuyển ...
# 1     [giao lưu, nhà báo, nhà thơ, nguyễn phong việt...
# 2     [phòng, công tác, sinh viên, thông tin, sinh v...
# 3     [chuyên ngành, đào tạo, trường, đại học, kansa...
# 4     [bật mí, chương trình, vô cùng, hấp dẫn, diễn,...
# ...                                                 ...
# 9135  [trường, nộp, giấy, kết quả, thi, thpt, quốc g...
# 9136  [đi, nha, share, kiểu, khai trương, group, sha...
# 9137  [chào, đỗ, ktpm, clc, khoa, làm quen, mail, ed...
# 9138  [chào, phòng, công tác, sinh viên, đăng tải, h...
# 9139                                  [thí sinh, lưu ý]
#
#                                                       2
# 0     tsđh thông báo tổ chức lớp ôn tập tuyển sinh c...
# 1     giao lưu nhà báo nhà thơ nguyễn phong việt phò...
# 2     phòng công tác sinh viên thông tin sinh viên l...
# 3     chuyên ngành đào tạo trường đại học kansai osa...
# 4     bật mí chương trình vô cùng hấp dẫn diễn nhà v...
# ...                                                 ...
# 9135  trường nộp giấy kết quả thi thpt quốc gia xác ...
# 9136  đi nha share kiểu khai trương group share mấy ...
# 9137  chào đỗ ktpm clc khoa làm quen mail edu trường...
# 9138  chào phòng công tác sinh viên đăng tải hướng d...
# 9139                                     thí sinh lưu ý
#
# [9140 rows x 3 columns]

# %%
dataset.to_csv('dataset.csv', index=False)
