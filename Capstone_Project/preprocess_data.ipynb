# %%
# -*- coding: utf-8 -*-
from underthesea import word_tokenize
import re
import VietnameseTextNormalizer.ReleasePython3.VietnameseTextNormalizer as nm
import pandas as pd
import numpy as np

# %%
def removeConsecutiveDuplicates(S): 
    S = list(S.rstrip()) 
    
    n = len(S)  
    
    if (n < 2) : 
        return S[0]
           
    j = 0
       
    for i in range(n):  
        if (S[j] != S[i]): 
            j += 1
            S[j] = S[i]  
      
    j += 1
    S = S[:j]
    return "".join(S)

# %%
def preprocessing(s, show_stepbystep=False):
    if show_stepbystep:
        print("original:")
        print(s)
        print()
    
    # remove 'Xem thêm'
    s = re.sub('Xem thêm', '', s)
    if show_stepbystep:
        print("remove xt:")
        print(s)
        print()

    # convert to lower case
    s = s.lower()
    if show_stepbystep:
        print("lowercase:")
        print(s)
        print()
    
    # normalize Vietnamese
    s = nm.ASRNormalize(s)
    if show_stepbystep:
        print("normalized Vietnamese:")
        print(s)
        print()
        
    # remove urls
    s = re.sub(r'http\S+', '', s)
    if show_stepbystep:
        print('remove urls:')
        print(s)
        print()
    
    # remove email address
    s = re.sub(r'\S*@\S*\s?', '', s)
    if show_stepbystep:
        print('remove email addresses:')
        print(s)
        print()
    
    # split into words
    tokens = word_tokenize(s)
    if show_stepbystep:
        print('tokenize:')
        print(tokens)
        print()
    
    # remove punctuation and number
    words = [word for word in tokens if re.sub(r"\s+", "", word).isalpha()]
    if show_stepbystep:
        print('remove punctuation:')
        print(words)
        print()
    
    # filter out stop words
    words = [word for word in words if not word in stop_words]
    if show_stepbystep:
        print('remove stop words:')
        print(words)
        print()
    
    # remove consecutive duplicates character
    words = [removeConsecutiveDuplicates(word) for word in words]
    if show_stepbystep:
        print('remove consecutive duplicates character:')
        print(words)
        print()
        
    # remove single character
    words = [word for word in words if len(word)>1]
    if show_stepbystep:
        print('remove single character:')
        print(words)
        print()
    
    return words

# %%
# load stop words list
file = open('vietnamese-stopwords.txt')
stop_words = file.readlines()
file.close()

stop_words = set([word.strip('\n') for word in stop_words])
stop_words
# Out:
# {'cho biết',
#  'tên tự',
#  'tuy nhiên',
#  'bất tử',
#  'của tin',
#  'tanh tanh',
#  'riêng',
#  'thấp',
#  'điều gì',
#  'cũng thế',
#  'bỏ nhỏ',
#  'mới rồi',
#  'đến giờ',
#  'oai oái',
#  'ô kìa',
#  'này nọ',
#  'tốt hơn',
#  'thành ra',
#  'bớ',
#  'qua lại',
#  'dùng',
#  'từ ái',
#  'thật ra',
#  'sau chót',
#  'vẫn thế',
#  'cô',
#  'ít thôi',
#  'nên tránh',
#  'lấy lý do',
#  'thường bị',
#  'thấy',
#  'thứ',
#  'ăn sáng',
#  'ừ nhé',
#  'cực lực',
#  'thường hay',
#  'khác thường',
#  'ví bằng',
#  'ra người',
#  'với',
#  'giảm thấp',
#  'gây',
#  'mỗi lúc',
#  'cho chắc',
#  'tênh',
#  'chắc người',
#  'vô kể',
#  'bởi chưng',
#  'điểm đầu tiên',
#  'cuốn',
#  'giống nhau',
#  'có cơ',
#  'chung cục',
#  'chưa chắc',
#  'xềnh xệch',
#  'thốt nói',
#  'giống như',
#  'thêm vào',
#  'trời đất ơi',
#  'giá trị',
#  'ngoải',
#  'những',
#  'béng',
#  'điểm gặp',
#  'khi nên',
#  'nhận làm',
#  'phần nhiều',
#  'tự tạo',
#  'thảo hèn',
#  'sang',
#  'cô mình',
#  'thật thà',
#  'lần trước',
#  'hết ý',
#  'qua khỏi',
#  'tới thì',
#  'ngày cấp',
#  'gần xa',
#  'đều bước',
#  'lấy lại',
#  'chao ôi',
#  'trả lại',
#  'mang lại',
#  'sắp đặt',
#  'chọn bên',
#  'cao răng',
#  'làm như',
#  'gặp',
#  'nghe lại',
#  'bất kì',
#  'nên chăng',
#  'dữ',
#  'đặc biệt',
#  'thường xuất hiện',
#  'nước quả',
#  'giảm thế',
#  'cho rồi',
#  'chính',
#  'thậm cấp',
#  'quay lại',
#  'vì',
#  'cậu',
#  'phía bên',
#  'phỏng nước',
#  'không có gì',
#  'vài nơi',
#  'chưa dùng',
#  'lâu',
#  'phải rồi',
#  'chu cha',
#  'ừ thì',
#  'ngày',
#  'chớ không',
#  'thật quả',
#  'đánh giá',
#  'làm riêng',
#  'chậc',
#  'nhờ đó',
#  'họ xa',
#  'mà không',
#  'tất thảy',
#  'gặp khó khăn',
#  'ăn quá',
#  'số loại',
#  'đầy',
#  'bài bỏ',
#  'lâu các',
#  'sau hết',
#  'tắp',
#  'ô kê',
#  'nhà việc',
#  'nhất nhất',
#  'chắc',
#  'ở đó',
#  'từ tính',
#  'còn như',
#  'sau sau',
#  'cho tới khi',
#  'giống người',
#  'nói thêm',
#  'thế thường',
#  'cơ chừng',
#  'nhìn nhận',
#  'cô quả',
#  'không cứ',
#  'lấy ra',
#  'tin vào',
#  'tháng năm',
#  'ăn',
#  'tuy thế',
#  'nhận việc',
#  'nhà ngoài',
#  'loại',
#  'cho được',
#  'đến lời',
#  'quá mức',
#  'xệp',
#  'dễ khiến',
#  'coi bộ',
#  'vậy ra',
#  'cuối điểm',
#  'qua',
#  'bởi thế',
#  'chúng ta',
#  'nên làm',
#  'có ai',
#  'cả nghe',
#  'của',
#  'nghĩ lại',
#  'cùng chung',
#  'dở chừng',
#  'bán cấp',
#  'sớm',
#  'cuối cùng',
#  'nói lên',
#  'sớm ngày',
#  'chuyển tự',
#  'nữa',
#  'chung qui',
#  'ra ý',
#  'nào',
#  'ừ ừ',
#  'cơn',
#  'dễ đâu',
#  'nơi nơi',
#  'ráo trọi',
#  'tránh xa',
#  'không đầy',
#  'nữa là',
#  'cùng với',
#  'thậm từ',
#  'ầu ơ',
#  'bao nả',
#  'mọi nơi',
#  'lần theo',
#  'tại',
#  'vài người',
#  'bằng như',
#  'tạo ra',
#  'nguồn',
#  'xem số',
#  'ngay tức thì',
#  'chưa kể',
#  'phù hợp',
#  'bản riêng',
#  'thế thì',
#  'ra lời',
#  'thế chuẩn bị',
#  'bị vì',
#  'nhanh',
#  'sở dĩ',
#  'quá tuổi',
#  'đưa tay',
#  'cho đang',
#  'xuống',
#  'chơi họ',
#  'do đó',
#  'ủa',
#  'đâu có',
#  'cơ mà',
#  'lúc đi',
#  'nhất tâm',
#  'phỉ phui',
#  'đâu đây',
#  'tự vì',
#  'nói phải',
#  'thà là',
#  'đâu nào',
#  'ngày xưa',
#  'cả thảy',
#  'vào đến',
#  'như ý',
#  'chầm chập',
#  'số người',
#  'lấy làm',
#  'ở năm',
#  'ấy là',
#  'thậm',
#  'hiểu',
#  'từng ấy',
#  'tên cái',
#  'bất nhược',
#  'ngày ấy',
#  'vậy ư',
#  'sự',
#  'thường sự',
#  'trước nay',
#  'tìm ra',
#  'ừ',
#  'nhất tề',
#  'thường thôi',
#  'đến xem',
#  'gần',
#  'ráo cả',
#  'thương ôi',
#  'chứ lại',
#  'bông',
#  'thấp cơ',
#  'bộ thuộc',
#  'ớ này',
#  'mọi giờ',
#  'rõ là',
#  'nhược bằng',
#  'bản',
#  'bất giác',
#  'dài ra',
#  'bằng người',
#  'ai',
#  'thích tự',
#  'ngay',
#  'tất tật',
#  'ít nhất',
#  'bà ấy',
#  'ông ổng',
#  'đã vậy',
#  'tấm các',
#  'ngay tức khắc',
#  'đúng',
#  'để đến nỗi',
#  'luôn cả',
#  'còn về',
#  'trả của',
#  'xa nhà',
#  'thình lình',
#  'lâu nay',
#  'chớ kể',
#  'rồi ra',
#  'cách không',
#  'tự ăn',
#  'thôi',
#  'duy có',
#  'giờ đây',
#  'tốt mối',
#  'đưa tới',
#  'hỏi xem',
#  'lấy vào',
#  'phải cách',
#  'quả thế',
#  'vô hình trung',
#  'than ôi',
#  'trong số',
#  'ngày xửa',
#  'làm lấy',
#  'xin',
#  'cho nên',
#  'cơ hội',
#  'dễ thường',
#  'nào hay',
#  'đặt làm',
#  'điểm',
#  'trước tiên',
#  'thà rằng',
#  'ở như',
#  'khác xa',
#  'các cậu',
#  'bấy',
#  'làm bằng',
#  'vô luận',
#  'nhưng mà',
#  'buổi',
#  'cu cậu',
#  'hiện tại',
#  'thế à',
#  'mỗi một',
#  'nhân tiện',
#  'thời gian tính',
#  'trực tiếp',
#  'nó',
#  'điểm chính',
#  'một cơn',
#  'hết nói',
#  'thế đó',
#  'kể từ',
#  'đang thì',
#  'cây',
#  'nghe nói',
#  'bên',
#  'vì vậy',
#  'cách đều',
#  'thái quá',
#  'sự thế',
#  'tốt',
#  'vài điều',
#  'trước đây',
#  'thuần',
#  'sau cùng',
#  'duy',
#  'ơ kìa',
#  'ngọn',
#  'nhìn chung',
#  'rồi sao',
#  'xuất kì bất ý',
#  'giờ này',
#  'qua thì',
#  'làm cho',
#  'thì thôi',
#  'khá tốt',
#  'bởi vậy',
#  'chỉ chính',
#  'số phần',
#  'cũng',
#  'kể như',
#  'toẹt',
#  'tin',
#  'có thể',
#  'như tuồng',
#  'thốt nhiên',
#  'nền',
#  'đã đủ',
#  'nói ra',
#  'là ít',
#  'buổi sớm',
#  'làm tắp lự',
#  'chỉn',
#  'khẳng định',
#  'khi không',
#  'qua ngày',
#  'tựu trung',
#  'vậy',
#  'bất cứ',
#  'ba tăng',
#  'phải',
#  'xem lại',
#  'nghĩ đến',
#  'tính phỏng',
#  'nói riêng',
#  'hay nhỉ',
#  'úi',
#  'xuất kỳ bất ý',
#  'các',
#  'đủ số',
#  'lấy có',
#  'lên ngôi',
#  'nói qua',
#  'phần việc',
#  'nhỡ ra',
#  'bà',
#  'thường đến',
#  'chưa từng',
#  'nọ',
#  'bỗng dưng',
#  'ra',
#  'hết cả',
#  'cao lâu',
#  'có chứ',
#  'trước nhất',
#  'mỗi người',
#  'trong đó',
#  'thà',
#  'nói xa',
#  'thêm',
#  'ít có',
#  'biết',
#  'thật sự',
#  'sáng rõ',
#  'dành dành',
#  'nhà làm',
#  'phải khi',
#  'giữ lấy',
#  'nhỉ',
#  'tiện thể',
#  'tại đó',
#  'gần đến',
#  'tiếp theo',
#  'làm gì',
#  'thực ra',
#  'được',
#  'đáng lẽ',
#  'thường thường',
#  'khó chơi',
#  'đầy năm',
#  'giảm chính',
#  'chớ',
#  'nhất định',
#  'thế mà',
#  'thi thoảng',
#  'sang năm',
#  'vào gặp',
#  'luôn',
#  'thực hiện',
#  'quay',
#  'về không',
#  'ngồi bệt',
#  'để được',
#  'người khác',
#  'nói với',
#  'từ căn',
#  'nhận nhau',
#  'để lòng',
#  'vừa',
#  'về phần',
#  'quá thì',
#  'khó thấy',
#  'nhớ',
#  'đưa',
#  'tắp tắp',
#  'lấy được',
#  'vậy nên',
#  'bắt đầu',
#  'ối giời',
#  'nhà khó',
#  'chết thật',
#  'ừ ào',
#  'xăm xắm',
#  'bước đi',
#  'năm tháng',
#  'trong',
#  'tại đâu',
#  'thế là',
#  'nhớ lấy',
#  'trong vùng',
#  'ái dà',
#  'khác',
#  'nhiều ít',
#  'nhìn theo',
#  'gây ra',
#  'vung tàn tán',
#  'bắt đầu từ',
#  'đến tuổi',
#  'riu ríu',
#  'cụ thể là',
#  'nhờ có',
#  'bỏ ra',
#  'vấn đề',
#  'thật là',
#  'hơn',
#  'tà tà',
#  'chủn',
#  'thiếu điểm',
#  'cha chả',
#  'thôi việc',
#  'khi trước',
#  'việc gì',
#  'bỏ bà',
#  'cơ cùng',
#  'giống',
#  'quay số',
#  'bằng nào',
#  'cả người',
#  'thế nào',
#  'ớ',
#  'thoạt nghe',
#  'không gì',
#  'biết việc',
#  'có khi',
#  'khỏi nói',
#  'như thể',
#  'thích thuộc',
#  'biết bao',
#  'lớn',
#  'phắt',
#  'tại tôi',
#  'không khỏi',
#  'cao sang',
#  'ngày ngày',
#  'bỏ mẹ',
#  'mà thôi',
#  'rồi',
#  'giờ đi',
#  'làm tôi',
#  'bèn',
#  'một lúc',
#  'cao',
#  'lên số',
#  'kể tới',
#  'bỏ cuộc',
#  'ngọt',
#  'giảm',
#  'chúng',
#  'vài nhà',
#  'tăng chúng',
#  'vừa mới',
#  'có số',
#  'dễ thấy',
#  'tuy rằng',
#  'ô hay',
#  'lâu ngày',
#  'mang',
#  'đưa đến',
#  'tuốt luốt',
#  'không thể',
#  'ra chơi',
#  'nơi',
#  'chắc hẳn',
#  'nhà',
#  'rồi đây',
#  'vị tất',
#  'từ khi',
#  'thêm giờ',
#  'chưa dễ',
#  'thật chắc',
#  'tránh khỏi',
#  'lại người',
#  'như quả',
#  'chưa có',
#  'phương chi',
#  'tìm việc',
#  'đã là',
#  'thẩy',
#  'thảo nào',
#  'chính điểm',
#  'dễ nghe',
#  'đối với',
#  'ào vào',
#  'mọi thứ',
#  'quay bước',
#  'như chơi',
#  'để phần',
#  'á',
#  'nói tốt',
#  'chăng chắc',
#  'nếu không',
#  'rén bước',
#  'chỉ tên',
#  'thanh tính',
#  'tháng',
#  'quá nhiều',
#  'giữ',
#  'tấm',
#  'bỏ việc',
#  'bởi ai',
#  'nhận ra',
#  'quan trọng',
#  'ở lại',
#  'ngăn ngắt',
#  'sao cho',
#  'điều',
#  'vì rằng',
#  'nhanh lên',
#  'nhất sinh',
#  'tức tốc',
#  'bấy nay',
#  'ít biết',
#  'nào phải',
#  'ra bài',
#  'nặng mình',
#  'sao bản',
#  'trong này',
#  'làm tin',
#  'ngày giờ',
#  'nhớ bập bõm',
#  'tha hồ',
#  'lên',
#  'đảm bảo',
#  'xa xả',
#  'thốc tháo',
#  'sự việc',
#  'làm vì',
#  'bộ điều',
#  'không chỉ',
#  'người',
#  'hơn hết',
#  'a lô',
#  'nhưng',
#  'thanh thanh',
#  'bây nhiêu',
#  'dữ cách',
#  'cùng',
#  'ái chà',
#  'trong ngoài',
#  'tay quay',
#  'vừa khi',
#  'lấy để',
#  'và',
#  'ôi chao',
#  'úi dào',
#  'cao thấp',
#  'thay đổi tình trạng',
#  'vị trí',
#  'rốt cục',
#  'nếu mà',
#  'bước tới',
#  'từ loại',
#  'một ít',
#  'dễ ăn',
#  'có phải',
#  'không điều kiện',
#  'cho đến nỗi',
#  'khi khác',
#  'ý hoặc',
#  'vì sao',
#  'xăm xúi',
#  'ái',
#  'bản bộ',
#  'cả nghĩ',
#  'nói rõ',
#  'cô tăng',
#  'bước khỏi',
#  'lúc lâu',
#  'đến thế',
#  'vâng ý',
#  'sì sì',
#  'hỏi',
#  'bấy chừ',
#  'tự cao',
#  'trước',
#  'là là',
#  'buổi làm',
#  'khó biết',
#  'những như',
#  'tạo',
#  'đưa ra',
#  'ngồi',
#  'quá lời',
#  'chung ái',
#  'sáng ý',
#  'đều',
#  'lại quả',
#  'lòng',
#  'biết mình',
#  'quá bán',
#  'thuộc từ',
#  'ứ hự',
#  'nấy',
#  'bán',
#  'là nhiều',
#  'chắc lòng',
#  'bất chợt',
#  'lấy xuống',
#  'mọi khi',
#  'có người',
#  'tại đây',
#  'chính là',
#  'nên chi',
#  'muốn',
#  'con dạ',
#  'vừa lúc',
#  'không bao giờ',
#  'người nhận',
#  'ít quá',
#  'gặp phải',
#  'bất quá chỉ',
#  'ra tay',
#  'nhờ nhờ',
#  'ơ',
#  'thật',
#  'tuyệt nhiên',
#  'lên cơn',
#  'lần nào',
#  'ví dù',
#  'có điều kiện',
#  'cũng vậy',
#  'khiến',
#  'cách bức',
#  'mà lại',
#  'tính cách',
#  'đã không',
#  'phụt',
#  'gì gì',
#  'nhất quyết',
#  'ba ngôi',
#  'cứ',
#  'đưa em',
#  'người người',
#  'cách nhau',
#  'tìm bạn',
#  'thay đổi',
#  'tênh tênh',
#  'ngày này',
#  'dạ',
#  'nói đủ',
#  'nhằm vào',
#  'lấy thêm',
#  'lớn nhỏ',
#  'lượng từ',
#  'đúng tuổi',
#  'khác nhau',
#  'ư',
#  'chuyển',
#  'cách',
#  'bài cái',
#  'tít mù',
#  'đánh đùng',
#  'dạ dạ',
#  'nhung nhăng',
#  'nếu thế',
#  'đưa về',
#  'như là',
#  'nói là',
#  'mọi việc',
#  'quả là',
#  'có nhiều',
#  'trước đó',
#  'qua lần',
#  'ăn ngồi',
#  'xon xón',
#  'không dùng',
#  'chịu',
#  'thoạt nhiên',
#  'nghe ra',
#  'thỏm',
#  'ăn tay',
#  'bây bẩy',
#  'căn cái',
#  'thực vậy',
#  'cứ điểm',
#  'thế thôi',
#  'vâng dạ',
#  'chia sẻ',
#  'ngôi thứ',
#  'dạ khách',
#  'bước',
#  'nghĩ ra',
#  'a ha',
#  'biết được',
#  'bài',
#  'rốt cuộc',
#  'số',
#  'ạ',
#  'rất',
#  'thục mạng',
#  'một khi',
#  'veo',
#  'nhà tôi',
#  'bỏ quá',
#  'ngày qua',
#  'nhằm để',
#  'cho rằng',
#  'ào',
#  'xa gần',
#  'là cùng',
#  'lần khác',
#  'biết đâu',
#  'nên',
#  'tất cả bao nhiêu',
#  'xoẹt',
#  'ít nhiều',
#  'tha hồ ăn',
#  'ăn làm',
#  'đại loại',
#  'hay không',
#  'cơ chỉ',
#  'không những',
#  'cái họ',
#  'ý',
#  'từng đơn vị',
#  'khác gì',
#  'phải giờ',
#  'thích ý',
#  'bỏ riêng',
#  'những muốn',
#  'chứ ai',
#  'khách',
#  'nào cũng',
#  'qua đi',
#  'dùng làm',
#  'dài',
#  'à này',
#  'tốt bạn',
#  'một',
#  'bán dạ',
#  'bán thế',
#  'còn nữa',
#  'ơ hay',
#  'khoảng cách',
#  'nhón nhén',
#  'xin gặp',
#  'áng',
#  'tớ',
#  'riệt',
#  'đặt ra',
#  'văng tê',
#  'nước nặng',
#  'sáng thế',
#  'tạo cơ hội',
#  'giờ lâu',
#  'giữa lúc',
#  'vài',
#  'thốt',
#  'chết tiệt',
#  'ăn chung',
#  'lúc khác',
#  'vâng',
#  'lên đến',
#  'đầy phè',
#  'dần dà',
#  'đặt trước',
#  'khỏi',
#  'ông tạo',
#  'nhỏ',
#  'không nhận',
#  'nhìn',
#  'dễ dùng',
#  'quận',
#  'nặng về',
#  'nên người',
#  'cùng cực',
#  'khó nghe',
#  'vậy mà',
#  'tránh',
#  'cứ như',
#  'cho thấy',
#  'đại phàm',
#  'đến nơi',
#  'ứ ừ',
#  'ở',
#  'nhau',
#  'phải tay',
#  'phải cái',
#  'đặt để',
#  'em',
#  'ngày càng',
#  'nói',
#  'phía trên',
#  'gì',
#  'dì',
#  'vào lúc',
#  'mạnh',
#  'nghỉm',
#  'em em',
#  'có nhà',
#  'nước xuống',
#  'hỏi lại',
#  'mọi',
#  'bên cạnh',
#  'trong mình',
#  'bỏ lại',
#  'ơi',
#  'dùng hết',
#  'bức',
#  'lại còn',
#  'làm',
#  'không còn',
#  'bây giờ',
#  'sao đang',
#  'tự lượng',
#  'đến hay',
#  'chành chạnh',
#  'lại ăn',
#  'vừa rồi',
#  'lúc',
#  'ăn trên',
#  'nhận họ',
#  'quá ư',
#  'nghe đâu như',
#  'tới gần',
#  'toé khói',
#  'á à',
#  'cái đã',
#  'vào vùng',
#  'khó khăn',
#  'hay hay',
#  'vạn nhất',
#  'đã thế',
#  'dù dì',
#  'được cái',
#  'thoạt',
#  'đang',
#  'còn',
#  'mất còn',
#  'nào đó',
#  'hay biết',
#  'cho đến khi',
#  'làm ngay',
#  'vùng nước',
#  'nghe không',
#  'thường khi',
#  'sau đây',
#  'bỏ mất',
#  'mọi người',
#  'choa',
#  'bởi vì',
#  'đưa cho',
#  'ông từ',
#  'quay đi',
#  'bỏ',
#  'coi mòi',
#  'chứ lị',
#  'có được',
#  'ờ',
#  'ở nhờ',
#  'tính từ',
#  'làm lòng',
#  'đúng ngày',
#  'đâu',
#  'rón rén',
#  'rất lâu',
#  'nhất luật',
#  'trước khi',
#  'hãy còn',
#  'đủ điều',
#  'chú mình',
#  'chúng tôi',
#  'bấy nhiêu',
#  'thuộc',
#  'ráo',
#  'chung',
#  'bập bà bập bõm',
#  'nhận được',
#  'cả ngày',
#  'từ ấy',
#  'xoét',
#  'căn tính',
#  'lòng không',
#  'quan trọng vấn đề',
#  'ý da',
#  'tránh ra',
#  'nghe hiểu',
#  'chung chung',
#  'nữa rồi',
#  'đến cùng',
#  'tuy là',
#  'ổng',
#  'tuổi tôi',
#  'nếu cần',
#  'vả lại',
#  'thuộc cách',
#  'phải người',
#  'khá',
#  'nghe nhìn',
#  'do',
#  'con nhà',
#  'thiếu gì',
#  'lấy sau',
#  'lần lần',
#  'nhằm khi',
#  'vì thế',
#  'áng như',
#  'toà',
#  'biết chừng nào',
#  'xoành xoạch',
#  'bất đồ',
#  'khoảng không',
#  'tốt ngày',
#  'ra điều',
#  'hay nói',
#  'cùng tột',
#  'tiếp tục',
#  'nặng',
#  'đưa chuyện',
#  'người hỏi',
#  'càng',
#  'ngay khi đến',
#  'bên bị',
#  'tuổi',
#  'ráo nước',
#  'gần bên',
#  'đến điều',
#  'thanh',
#  'xiết bao',
#  ...}

# %%
k13 = pd.read_csv("k13/posts_1594221437_1.csv", header=None)
k14 = pd.read_csv("k14/posts_1594216235_1.csv", header=None)

# %%
to = pd.concat([k13, k14], ignore_index=True)
print(type(to), to.shape, k13.shape, k14.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'> (2137, 1) (1531, 1) (606, 1)

# %%
to
# Out:
#                                                       0
# 0     Háo hức quá chừng luôn á, ngày mai là biết đượ...
# 1     Cùng đến với chuỗi Training của Ban học tập để...
# 2                         Bạn nào rớt ra nhà xe lấy nhe
# 3                  [WannaGame-Weekly]\nTìm đồng độiiiii
# 4     Khoảng từ 12h20 đến 1h20 chiều nay ở gần cổng ...
# ...                                                 ...
# 2132             #CE121 Lý thuyết Mạch điện nha mấy đứa
# 2133  Cho mk hỏi mk đóng hc phí onl nhưng khi bấm xá...
# 2134  Chào mọi người,\nHọc kỳ 2 hình như không có mở...
# 2135                            tham gia nào các bạn :v
# 2136  Phòng Công tác Sinh viên thông báo nộp hồ sơ m...
#
# [2137 rows x 1 columns]

# %%
to[1] = [preprocessing(to.iloc[i][0]) for i in range(to.shape[0])]

# %%
to[2] = [' '.join(to.iloc[i][1]) for i in range(to.shape[0])]

# %%
to
# Out:
#                                                       0  \
# 0     Háo hức quá chừng luôn á, ngày mai là biết đượ...
# 1     Cùng đến với chuỗi Training của Ban học tập để...
# 2                         Bạn nào rớt ra nhà xe lấy nhe
# 3                  [WannaGame-Weekly]\nTìm đồng độiiiii
# 4     Khoảng từ 12h20 đến 1h20 chiều nay ở gần cổng ...
# ...                                                 ...
# 2132             #CE121 Lý thuyết Mạch điện nha mấy đứa
# 2133  Cho mk hỏi mk đóng hc phí onl nhưng khi bấm xá...
# 2134  Chào mọi người,\nHọc kỳ 2 hình như không có mở...
# 2135                            tham gia nào các bạn :v
# 2136  Phòng Công tác Sinh viên thông báo nộp hồ sơ m...
#
#                                                       1  \
# 0     [háo hức, quá chừng, ngày mai, ròi, ngày mai, ...
# 1     [chuỗi, training, ban, học tập, ôn tập, kiến t...
# 2                                    [rớt, nhà xe, nhe]
# 3                          [wanagame, wekly, đồng, đội]
# 4     [chiều, cổng, trưởng, rơi, điện thoại, xepria,...
# ...                                                 ...
# 2132             [lý thuyết, mạch, điện, nha, mấy, đứa]
# 2133  [mk, mk, đóng, hc, phí, onl, bấm, xác nhận, hi...
# 2134  [chào, học kỳ, hình như, lớp, kiến trúc, máy t...
# 2135                                         [tham gia]
# 2136  [phòng, công tác, sinh viên, thông báo, nộp, h...
#
#                                                       2
# 0     háo hức quá chừng ngày mai ròi ngày mai phòng ...
# 1     chuỗi training ban học tập ôn tập kiến thức kỳ...
# 2                                        rớt nhà xe nhe
# 3                               wanagame wekly đồng đội
# 4     chiều cổng trưởng rơi điện thoại xepria màu và...
# ...                                                 ...
# 2132                    lý thuyết mạch điện nha mấy đứa
# 2133         mk mk đóng hc phí onl bấm xác nhận hiện ln
# 2134  chào học kỳ hình như lớp kiến trúc máy tính đạ...
# 2135                                           tham gia
# 2136  phòng công tác sinh viên thông báo nộp hồ sơ m...
#
# [2137 rows x 3 columns]

# %%
to = to.drop_duplicates(ignore_index=True, subset=2)
to.shape
# Out:
# (1830, 3)

# %%
to
# Out:
#                                                       0  \
# 0     Háo hức quá chừng luôn á, ngày mai là biết đượ...
# 1     Cùng đến với chuỗi Training của Ban học tập để...
# 2                         Bạn nào rớt ra nhà xe lấy nhe
# 3                  [WannaGame-Weekly]\nTìm đồng độiiiii
# 4     Khoảng từ 12h20 đến 1h20 chiều nay ở gần cổng ...
# ...                                                 ...
# 1825  Gấp gấp các bạn ơi, bạn nào chưa có lớp Av 1 t...
# 1826  Tài liệu Giải tích đã được update, mọi người t...
# 1827             #CE121 Lý thuyết Mạch điện nha mấy đứa
# 1828  Cho mk hỏi mk đóng hc phí onl nhưng khi bấm xá...
# 1829  Phòng Công tác Sinh viên thông báo nộp hồ sơ m...
#
#                                                       1  \
# 0     [háo hức, quá chừng, ngày mai, ròi, ngày mai, ...
# 1     [chuỗi, training, ban, học tập, ôn tập, kiến t...
# 2                                    [rớt, nhà xe, nhe]
# 3                          [wanagame, wekly, đồng, đội]
# 4     [chiều, cổng, trưởng, rơi, điện thoại, xepria,...
# ...                                                 ...
# 1825                       [gấp, gấp, lớp, av, đăng ký]
# 1826  [tài liệu, giải tích, update, tranh thủ, ôn tậ...
# 1827             [lý thuyết, mạch, điện, nha, mấy, đứa]
# 1828  [mk, mk, đóng, hc, phí, onl, bấm, xác nhận, hi...
# 1829  [phòng, công tác, sinh viên, thông báo, nộp, h...
#
#                                                       2
# 0     háo hức quá chừng ngày mai ròi ngày mai phòng ...
# 1     chuỗi training ban học tập ôn tập kiến thức kỳ...
# 2                                        rớt nhà xe nhe
# 3                               wanagame wekly đồng đội
# 4     chiều cổng trưởng rơi điện thoại xepria màu và...
# ...                                                 ...
# 1825                             gấp gấp lớp av đăng ký
# 1826     tài liệu giải tích update tranh thủ ôn tập nha
# 1827                    lý thuyết mạch điện nha mấy đứa
# 1828         mk mk đóng hc phí onl bấm xác nhận hiện ln
# 1829  phòng công tác sinh viên thông báo nộp hồ sơ m...
#
# [1830 rows x 3 columns]

# %%
to.to_csv('to.csv', index=False)
